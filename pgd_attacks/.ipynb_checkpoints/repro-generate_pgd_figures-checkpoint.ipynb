# %% [markdown]
# # Display Examples

# %%
import numpy as np
import tensorflow as tf
from tensorflow.python.client import device_lib
from sklearn import metrics
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import auc
import numpy as np
import os
from keras.models import load_model

from keras.backend.tensorflow_backend import set_session
from utils import *

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.4
set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.

# %%
from copy import copy
def deprocess_inception(y):
    x = copy(y).astype(np.float)
    x += 1.
    x /= 2.
    #x *= 255.
    return x

def preprocess_inception(y):
    x = copy(y).astype(np.float)
    x /= 255.
    x *= 2.
    x -= 1.
    return x

def calc_pert(img_num, x_true, x_adv):
    return deprocess_inception(x_adv[img_num] - x_true[img_num])

import matplotlib.pyplot as plt
def display_adv_examples(imgNum, X_test_adv,
                         model, X_test, y_test,
                         verbose = False, X_test_bb = None):
    if verbose:
        print('Truth: ' + str(y_test[imgNum:imgNum+1]) )
        print('Model predict on true image: ' + str(model.predict(X_test[imgNum:imgNum+1])))
        print('Model predict on adversarial image: ' + str(model.predict(X_test_adv[imgNum:imgNum+1])))
        if X_test_bb is not None:
            print('Model predict on BB adversarial image: ' + str(model.predict(X_test_bb[imgNum:imgNum+1])))
        print("")

    plt.figure()
    print("True Image Deprocessed:")
    img = plt.imshow(deprocess_inception(X_test[imgNum]))
    img.set_cmap('hot')
    plt.axis('off')
    plt.show()

    print("Adversarial Image Deprocessed:")
    plt.figure()
    img = plt.imshow(deprocess_inception(X_test_adv[imgNum]))
    img.set_cmap('hot')
    plt.axis('off')
    plt.show()

    print("Perturbation*20:")
    plt.figure()
    img = plt.imshow(deprocess_inception((X_test_adv[imgNum] - X_test[imgNum])*20))
    img.set_cmap('hot')
    plt.axis('off')
    plt.show()

# %%
import os
def getResults(directory, model = None):
    X_test = np.load(os.path.join(directory, 'data/val_test_x_preprocess.npy'), mmap_mode = "r")
    y_test = np.load(os.path.join(directory, 'data/val_test_y.npy'))

    X_test_pgd = np.load(os.path.join(directory, 'data/pgd_eps02_WhiteBox.npy'), mmap_mode = "r")
    X_test_pgd_bb = np.load(os.path.join(directory, 'data/pgd_eps02_BlackBox.npy'), mmap_mode = "r")
    
    if model:
        preds_clean = model.predict(X_test)
        np.save('data/winning_model_preds.npy', preds_clean)
    
    return (X_test, y_test, X_test_pgd, X_test_pgd_bb)

# %%
print("Retinopathy / dr")
base_dir = '/projects/steinbac/adversarial_medical_imaging/dr'
model = load_model(f'{base_dir}/wb_model.h5')
model.summary()
# Out:
# Retinopathy / dr
# WARNING:tensorflow:From /home/steinbac/.local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/steinbac/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/steinbac/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 55, 55, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 55, 55, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 55, 55, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 55, 55, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 55, 55, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 55, 55, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 55, 55, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 55, 55, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 55, 55, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 55, 55, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None,
0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          262272      flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            258         dropout_1[0][0]
# ==================================================================================================
# Total params: 23,850,242
# Trainable params: 23,797,122
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
(X_test, dr_y_test,
 X_test_pgd_wb, X_test_pgd_bb) = getResults(base_dir)
print("x",X_test.shape, X_test.dtype)
print("y",dr_y_test.shape, dr_y_test.dtype)
print("first_12",X_test[:12].shape)
first_12 = model.predict(X_test[:12])
i = 0
for p in first_12:
    obs = p
    exp = dr_y_test[i]
    print(obs,exp)
    i += 1
# Out:
# x (10644, 224, 224, 3) float32
# y (10644, 2) float64
# first_12 (12, 224, 224, 3)
# [0.95733196 0.04266808] [1. 0.]
# [0.97897583 0.02102418] [1. 0.]
# [0.8040421  0.19595794] [1. 0.]
# [0.992599   0.00740099] [1. 0.]
# [0.74600524 0.2539948 ] [1. 0.]
# [0.98657215 0.01342779] [1. 0.]
# [0.9423507  0.05764928] [1. 0.]
# [0.973797   0.02620294] [1. 0.]
# [0.98008025 0.01991977] [1. 0.]
# [0.9065742 0.0934258] [1. 0.]
# [0.9739368  0.02606321] [1. 0.]
# [0.783952 0.216048] [1. 0.]

# %%
display_adv_examples(15, X_test_pgd_wb, model, X_test, dr_y_test, verbose = True, X_test_bb = X_test_pgd_bb)
display_adv_examples(10640, X_test_pgd_wb, model, X_test, dr_y_test, verbose = True, X_test_bb = X_test_pgd_bb)
# Out:
# Truth: [[1. 0.]]
# Model predict on true image: [[0.95175016 0.04824981]]
# Model predict on adversarial image: [[1.2422442e-10 1.0000000e+00]]
# Model predict on BB adversarial image: [[7.3749965e-05 9.9992621e-01]]
#
# True Image Deprocessed:
# Adversarial Image Deprocessed:
# Perturbation*20:
# Truth: [[0. 1.]]
# Model predict on true image: [[0.01415533 0.9858446 ]]
# Model predict on adversarial image: [[1.0000000e+00 2.0053404e-08]]
# Model predict on BB adversarial image: [[9.9909365e-01 9.0640254e-04]]
#
# True Image Deprocessed:
# Adversarial Image Deprocessed:
# Perturbation*20:

# %%
# foolbox based attack

import foolbox
from foolbox.models import KerasModel
from foolbox.attacks import LBFGSAttack
from foolbox.criteria import TargetClassProbability

fmodel = KerasModel(model, bounds=(-1., 1.))

# run the attack
#attack = LBFGSAttack(model=fmodel, criterion=TargetClassProbability(1, p=.7))
#attack  = foolbox.attacks.FGSM(fmodel)
attack = foolbox.attacks.SaltAndPepperNoiseAttack(model=fmodel, criterion=TargetClassProbability(1, p=.7))
image = np.asarray(X_test[1:2,...])
print(f"image of {image.shape} loaded")

kpred = model.predict(image)
print(f"model.predict labels of {np.argmax(kpred)} ({kpred}, {kpred.shape})")

pred  = fmodel.predictions(image[0])
label = np.argmax(pred)
print(f"fmodel.predictions labels of {label} {label.shape} ({pred}, {pred.shape})")
# Out:
# image of (1, 224, 224, 3) loaded
# model.predict labels of 0 ([[0.97897583 0.02102419]], (1, 2))
# fmodel.predictions labels of 0 () ([ 2.249041  -1.5917922], (2,))

# %%
print("min,max,mean,sd",np.max(image),np.min(image),np.mean(image),np.std(image) )
adversarial = attack( image[0] , label)
# Out:
# min,max,mean,sd 0.81960785 -1.0 -0.49528825 0.37258947

# %%
## print(adversarial.shape)
print(np.argmax(fmodel.predictions(adversarial)), label)

plt.figure()
print("True Image Deprocessed:")
img = plt.imshow(deprocess_inception(image[0]))
img.set_cmap('hot')
plt.axis('off')
plt.show()

print("Adversarial Image Deprocessed:")
plt.figure()
img = plt.imshow(deprocess_inception(adversarial))
img.set_cmap('hot')
plt.axis('off')
plt.show()

diff = (adversarial - image[0])
print("Perturbation*20:")
plt.figure()
img = plt.imshow(deprocess_inception((diff)*20))
img.set_cmap('hot')
plt.axis('off')
plt.show()

print(np.histogram(diff))
# Out:
# 1 0
# True Image Deprocessed:
# Adversarial Image Deprocessed:
# Perturbation*20:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (array([     5,      5,      6, 150500,      0,      0,      0,      4,
#             3,      5]), array([-1.2235295 , -0.9011765 , -0.57882357, -0.25647062,  0.06588233,
#         0.38823527,  0.7105882 ,  1.0329411 ,  1.3552941 ,  1.6776471 ,
#         2.        ], dtype=float32))

# %%
attack2 = foolbox.attacks.PointwiseAttack(model=fmodel, criterion=TargetClassProbability(1, p=.7))

adversarial2 = attack2(image[0] , label, starting_point=adversarial)

# %%
# print(adversarial.shape)
print(np.argmax(fmodel.predictions(adversarial2)), label)

plt.figure()
print("True Image Deprocessed:")
img = plt.imshow(deprocess_inception(image[0]))
img.set_cmap('hot')
plt.axis('off')
plt.show()

print("Adversarial Image Deprocessed:")
plt.figure()
img = plt.imshow(deprocess_inception(adversarial2))
img.set_cmap('hot')
plt.axis('off')
plt.show()

diff = (adversarial2 - image[0])
print("Perturbation*20:")
plt.figure()
img = plt.imshow(deprocess_inception(diff*20))
img.set_cmap('hot')
plt.axis('off')
plt.show()

print(np.histogram(diff))
# Out:
# 1 0
# True Image Deprocessed:
# Adversarial Image Deprocessed:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perturbation*20:
# (array([     2,      0, 150525,      0,      0,      0,      0,      0,
#             0,      1]), array([-0.60355395, -0.39966914, -0.19578433,  0.00810048,  0.21198529,
#         0.4158701 ,  0.6197549 ,  0.82363975,  1.0275245 ,  1.2314093 ,
#         1.4352942 ], dtype=float32))

# %%
attack3 = foolbox.attacks.BoundaryAttack(model=fmodel, criterion=TargetClassProbability(1, p=.7))

adversarial3 = attack3(image[0] , label, starting_point=adversarial)
# Out:
# run with verbose=True to see details
# Step 0: 6.71173e-05, stepsizes = 1.0e-02/1.0e-02:
# Step 1: 6.57817e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.3356e-06) (took 0.04092 seconds)
# Step 2: 6.44726e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.3091e-06) (took 0.02942 seconds)
# Step 3: 6.31896e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.2830e-06) (took 0.02412 seconds)
# Step 4: 6.19322e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.2575e-06) (took 0.02342 seconds)
# Step 5: 6.06997e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.2324e-06) (took 0.02561 seconds)
# Step 6: 5.94918e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.2079e-06) (took 0.02138 seconds)
# Step 7: 5.83079e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.1839e-06) (took 0.02577 seconds)
# Step 8: 5.71476e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.1603e-06) (took 0.02519 seconds)
# Step 9: 5.60103e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.1372e-06) (took 0.02529 seconds)
# Step 10: 5.48957e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.1146e-06) (took 0.03882 seconds)
# Step 11: 5.38033e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.0924e-06) (took 0.02755 seconds)
# Step 12: 5.27326e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.0707e-06) (took 0.02779 seconds)
# Step 13: 5.16832e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.0494e-06) (took 0.03208 seconds)
# Step 14: 5.06547e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.0285e-06) (took 0.02263 seconds)
# Step 15: 4.96467e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (1.0080e-06) (took 0.02195 seconds)
# Step 16: 4.86587e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (9.8797e-07) (took 0.02091 seconds)
# Step 17: 4.76904e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (9.6831e-07) (took 0.02122 seconds)
# Step 18: 4.67414e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (9.4904e-07) (took 0.02360 seconds)
# Step 19: 4.58112e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (9.3015e-07) (took 0.02338 seconds)
# Step 20: 4.48996e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (9.1164e-07) (took 0.04085 seconds)
# Step 21: 4.40061e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (8.9350e-07) (took 0.02331 seconds)
# Step 22: 4.31304e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (8.7572e-07) (took 0.02137 seconds)
# Step 23: 4.22721e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (8.5829e-07) (took 0.02272 seconds)
# Step 24: 4.14309e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (8.4121e-07) (took 0.02131 seconds)
# Step 25: 4.06064e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (8.2447e-07) (took 0.02285 seconds)
# Step 26: 3.97983e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (8.0807e-07) (took 0.02258 seconds)
# Step 27: 3.90063e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (7.9199e-07) (took 0.02302 seconds)
# Step 28: 3.82301e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (7.7623e-07) (took 0.02227 seconds)
# Step 29: 3.74693e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (7.6078e-07) (took 0.02176 seconds)
# Step 30: 3.67237e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (7.4564e-07) (took 0.03702 seconds)
# Step 31: 3.59929e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (7.3080e-07) (took 0.02122 seconds)
# Step 32: 3.52766e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (7.1626e-07) (took 0.02280 seconds)
# Step 33: 3.45746e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (7.0201e-07) (took 0.02337 seconds)
# Step 34: 3.38866e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (6.8803e-07) (took 0.02123 seconds)
# Step 35: 3.32122e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (6.7434e-07) (took 0.02212 seconds)
# Step 36: 3.25513e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (6.6092e-07) (took 0.02243 seconds)
# Step 37: 3.19036e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (6.4777e-07) (took 0.02225 seconds)
# Step 38: 3.12687e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (6.3488e-07) (took 0.02249 seconds)
# Step 39: 3.06464e-05, stepsizes = 1.0e-02/1.0e-02: d. reduced by 1.99% (6.2225e-07) (took 0.05096 seconds)
# Step 40: 3.06464e-05, stepsizes = 1.0e-02/1.0e-02:  (took 0.67022 seconds)
# Step 41: 3.06464e-05, stepsizes = 1.0e-02/1.0e-02:  (took 0.38302 seconds)
# Step 42: 3.06464e-05, stepsizes = 1.0e-02/1.0e-02:  (took 0.37636 seconds)
# Step 43: 3.06464e-05, stepsizes = 1.0e-02/1.0e-02:  (took 0.38668 seconds)
# Step 44: 3.06464e-05, stepsizes = 1.0e-02/1.0e-02:  (took 0.36568 seconds)
# Step 45: 3.06464e-05, stepsizes = 1.0e-02/1.0e-02:  (took 0.38201 seconds)
# Step 46: 3.06464e-05, stepsizes = 1.0e-02/1.0e-02:  (took 0.38452 seconds)
# Step 47: 3.06464e-05, stepsizes = 1.0e-02/1.0e-02:  (took 0.38154 seconds)
# Step 48: 3.06464e-05, stepsizes = 1.0e-02/1.0e-02:  (took 0.39779 seconds)
# Step 49: 3.06464e-05, stepsizes = 1.0e-02/1.0e-02:  (took 0.39536 seconds)
# Step 50: 3.06464e-05, stepsizes = 1.0e-02/6.7e-03:  (took 0.61800 seconds)
# Step 51: 3.06464e-05, stepsizes = 1.0e-02/6.7e-03:  (took 0.37481 seconds)
# Step 111: 2.90513e-05, stepsizes = 1.5e-02/4.4e-03:  (took 0.12914 seconds)
# Step 112: 2.90513e-05, stepsizes = 1.5e-02/4.4e-03:  (took 0.13299 seconds)
# Step 113: 2.90513e-05, stepsizes = 1.5e-02/4.4e-03:  (took 0.12937 seconds)
# Step 114: 2.90513e-05, stepsizes = 1.5e-02/4.4e-03:  (took 0.13098 seconds)
# Step 115: 2.90513e-05, stepsizes = 1.5e-02/4.4e-03:  (took 0.13420 seconds)
# Step 116: 2.90513e-05, stepsizes = 1.5e-02/4.4e-03:  (took 0.13262 seconds)
# Step 117: 2.90513e-05, stepsizes = 1.5e-02/4.4e-03:  (took 0.13396 seconds)
# Step 118: 2.90513e-05, stepsizes = 1.5e-02/4.4e-03:  (took 0.13369 seconds)
# Step 119: 2.87937e-05, stepsizes = 1.5e-02/4.4e-03: d. reduced by 0.89% (2.5766e-07) (took 0.06933 seconds)
# Step 120: 2.87937e-05, stepsizes = 2.2e-02/4.4e-03:  (took 0.21741 seconds)
# Step 121: 2.85383e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.5537e-07) (took 0.11626 seconds)
# Step 122: 2.82852e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.5311e-07) (took 0.07636 seconds)
# Step 123: 2.80343e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.5087e-07) (took 0.12244 seconds)
# Step 124: 2.80343e-05, stepsizes = 2.2e-02/4.4e-03:  (took 0.13411 seconds)
# Step 125: 2.80343e-05, stepsizes = 2.2e-02/4.4e-03:  (took 0.14053 seconds)
# Step 126: 2.77857e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.4864e-07) (took 0.07206 seconds)
# Step 127: 2.75392e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.4643e-07) (took 0.07030 seconds)
# Step 128: 2.72950e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.4425e-07) (took 0.06676 seconds)
# Step 129: 2.70529e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.4208e-07) (took 0.06892 seconds)
# Step 130: 2.68130e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.3994e-07) (took 0.13255 seconds)
# Step 131: 2.65752e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.3781e-07) (took 0.07211 seconds)
# Step 132: 2.63395e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.3570e-07) (took 0.11513 seconds)
# Step 133: 2.61059e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.3361e-07) (took 0.06812 seconds)
# Step 134: 2.58743e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.3154e-07) (took 0.07135 seconds)
# Step 135: 2.56448e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.2948e-07) (took 0.06867 seconds)
# Step 136: 2.54174e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.2745e-07) (took 0.06918 seconds)
# Step 137: 2.51920e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.2543e-07) (took 0.11610 seconds)
# Step 138: 2.49685e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.2343e-07) (took 0.07084 seconds)
# Step 139: 2.47471e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.2145e-07) (took 0.11749 seconds)
# Step 140: 2.45276e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.1949e-07) (took 0.10637 seconds)
# Step 141: 2.43100e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.1754e-07) (took 0.07112 seconds)
# Step 142: 2.40944e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.1561e-07) (took 0.11748 seconds)
# Step 143: 2.38807e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.1370e-07) (took 0.07119 seconds)
# Step 144: 2.36689e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.1180e-07) (took 0.06997 seconds)
# Step 145: 2.34590e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.0992e-07) (took 0.11879 seconds)
# Step 146: 2.32510e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.0806e-07) (took 0.07251 seconds)
# Step 147: 2.30447e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.0622e-07) (took 0.07017 seconds)
# Step 148: 2.30447e-05, stepsizes = 2.2e-02/4.4e-03:  (took 0.13559 seconds)
# Step 149: 2.28404e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.0439e-07) (took 0.06899 seconds)
# Step 150: 2.26378e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.0257e-07) (took 0.19234 seconds)
# Step 151: 2.24370e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (2.0078e-07) (took 0.07210 seconds)
# Step 152: 2.24370e-05, stepsizes = 2.2e-02/4.4e-03:  (took 0.12986 seconds)
# Step 153: 2.22380e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (1.9900e-07) (took 0.11495 seconds)
# Step 154: 2.20408e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (1.9723e-07) (took 0.07029 seconds)
# Step 155: 2.20408e-05, stepsizes = 2.2e-02/4.4e-03:  (took 0.13142 seconds)
# Step 156: 2.18453e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (1.9548e-07) (took 0.06899 seconds)
# Step 157: 2.16515e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (1.9375e-07) (took 0.07139 seconds)
# Step 158: 2.14595e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (1.9203e-07) (took 0.06763 seconds)
# Step 159: 2.12692e-05, stepsizes = 2.2e-02/4.4e-03: d. reduced by 0.89% (1.9033e-07) (took 0.07260 seconds)
# Step 160: 2.10805e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.89% (1.8864e-07) (took 0.12844 seconds)
# Step 161: 2.09558e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.2474e-07) (took 0.06717 seconds)
# Step 162: 2.08318e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.2400e-07) (took 0.06695 seconds)
# Step 163: 2.07085e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.2326e-07) (took 0.06336 seconds)
# Step 164: 2.05860e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.2254e-07) (took 0.06856 seconds)
# Step 165: 2.05860e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.13031 seconds)
# Step 166: 2.05860e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.13624 seconds)
# Step 167: 2.04642e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.2181e-07) (took 0.07342 seconds)
# Step 168: 2.03431e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.2109e-07) (took 0.11460 seconds)
# Step 169: 2.02227e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.2037e-07) (took 0.06899 seconds)
# Step 170: 2.02227e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.23584 seconds)
# Step 171: 2.01031e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.1966e-07) (took 0.07155 seconds)
# Step 172: 2.01031e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.14693 seconds)
# Step 173: 2.01031e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.13633 seconds)
# Step 174: 1.99841e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.1895e-07) (took 0.11556 seconds)
# Step 175: 1.99841e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.13030 seconds)
# Step 176: 1.98659e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.1825e-07) (took 0.07218 seconds)
# Step 177: 1.98659e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.13129 seconds)
# Step 178: 1.97483e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.1755e-07) (took 0.06925 seconds)
# Step 179: 1.97483e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.12925 seconds)
# Step 180: 1.96315e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.1685e-07) (took 0.10626 seconds)
# Step 181: 1.96315e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.13155 seconds)
# Step 182: 1.95153e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.1616e-07) (took 0.06766 seconds)
# Step 183: 1.93998e-05, stepsizes = 2.2e-02/3.0e-03: d. reduced by 0.59% (1.1547e-07) (took 0.07099 seconds)
# Step 184: 1.93998e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.12582 seconds)
# Step 185: 1.93998e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.13063 seconds)
# Step 186: 1.93998e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.13826 seconds)
# Step 187: 1.93998e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.13104 seconds)
# Step 188: 1.93998e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.13000 seconds)
# Step 189: 1.93998e-05, stepsizes = 2.2e-02/3.0e-03:  (took 0.13652 seconds)
# Step 190: 1.93998e-05, stepsizes = 3.4e-02/3.0e-03:  (took 0.19129 seconds)
# Step 191: 1.92850e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.1479e-07) (took 0.07274 seconds)
# Step 192: 1.92850e-05, stepsizes = 3.4e-02/3.0e-03:  (took 0.13329 seconds)
# Step 193: 1.91709e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.1411e-07) (took 0.06939 seconds)
# Step 194: 1.90575e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.1344e-07) (took 0.06847 seconds)
# Step 195: 1.89447e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.1277e-07) (took 0.06812 seconds)
# Step 196: 1.88326e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.1210e-07) (took 0.06931 seconds)
# Step 197: 1.87212e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.1144e-07) (took 0.07055 seconds)
# Step 198: 1.86104e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.1078e-07) (took 0.06791 seconds)
# Step 199: 1.85003e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.1012e-07) (took 0.06768 seconds)
# Step 200: 1.83908e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.0947e-07) (took 0.17891 seconds)
# Step 201: 1.82820e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.0882e-07) (took 0.12677 seconds)
# Step 202: 1.82820e-05, stepsizes = 3.4e-02/3.0e-03:  (took 0.13561 seconds)
# Step 203: 1.82820e-05, stepsizes = 3.4e-02/3.0e-03:  (took 0.13064 seconds)
# Step 204: 1.81738e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.0818e-07) (took 0.07218 seconds)
# Step 205: 1.80663e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.0754e-07) (took 0.06786 seconds)
# Step 206: 1.79594e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.0690e-07) (took 0.06971 seconds)
# Step 207: 1.78531e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (1.0627e-07) (took 0.06754 seconds)
# Step 254: 1.42486e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (8.4813e-08) (took 0.07396 seconds)
# Step 255: 1.42486e-05, stepsizes = 3.4e-02/3.0e-03:  (took 0.13700 seconds)
# Step 256: 1.41643e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (8.4311e-08) (took 0.07021 seconds)
# Step 257: 1.41643e-05, stepsizes = 3.4e-02/3.0e-03:  (took 0.13494 seconds)
# Step 258: 1.40805e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (8.3812e-08) (took 0.13672 seconds)
# Step 259: 1.39972e-05, stepsizes = 3.4e-02/3.0e-03: d. reduced by 0.59% (8.3316e-08) (took 0.13876 seconds)
# Step 260: 1.39972e-05, stepsizes = 3.4e-02/2.0e-03:  (took 0.19874 seconds)
# Step 261: 1.39419e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.5243e-08) (took 0.07103 seconds)
# Step 262: 1.39419e-05, stepsizes = 3.4e-02/2.0e-03:  (took 0.13207 seconds)
# Step 263: 1.38869e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.5025e-08) (took 0.07089 seconds)
# Step 264: 1.38321e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.4808e-08) (took 0.06854 seconds)
# Step 265: 1.37775e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.4591e-08) (took 0.06617 seconds)
# Step 266: 1.37231e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.4376e-08) (took 0.06704 seconds)
# Step 267: 1.36690e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.4161e-08) (took 0.06716 seconds)
# Step 268: 1.36690e-05, stepsizes = 3.4e-02/2.0e-03:  (took 0.12892 seconds)
# Step 269: 1.36690e-05, stepsizes = 3.4e-02/2.0e-03:  (took 0.13195 seconds)
# Step 270: 1.36150e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.3947e-08) (took 0.10956 seconds)
# Step 271: 1.35613e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.3735e-08) (took 0.06930 seconds)
# Step 272: 1.35078e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.3522e-08) (took 0.06827 seconds)
# Step 273: 1.35078e-05, stepsizes = 3.4e-02/2.0e-03:  (took 0.13329 seconds)
# Step 274: 1.34544e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.3311e-08) (took 0.06835 seconds)
# Step 275: 1.34544e-05, stepsizes = 3.4e-02/2.0e-03:  (took 0.12954 seconds)
# Step 276: 1.34544e-05, stepsizes = 3.4e-02/2.0e-03:  (took 0.13123 seconds)
# Step 277: 1.34544e-05, stepsizes = 3.4e-02/2.0e-03:  (took 0.13176 seconds)
# Step 278: 1.34013e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.3101e-08) (took 0.06736 seconds)
# Step 279: 1.33485e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.2891e-08) (took 0.11473 seconds)
# Step 280: 1.32958e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.2682e-08) (took 0.10931 seconds)
# Step 281: 1.32433e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.2475e-08) (took 0.11774 seconds)
# Step 282: 1.31910e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.2268e-08) (took 0.07015 seconds)
# Step 283: 1.31910e-05, stepsizes = 3.4e-02/2.0e-03:  (took 0.13148 seconds)
# Step 284: 1.31390e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.2061e-08) (took 0.11453 seconds)
# Step 285: 1.30871e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.1856e-08) (took 0.07285 seconds)
# Step 286: 1.30871e-05, stepsizes = 3.4e-02/2.0e-03:  (took 0.13472 seconds)
# Step 287: 1.30871e-05, stepsizes = 3.4e-02/2.0e-03:  (took 0.13505 seconds)
# Step 288: 1.30355e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.1651e-08) (took 0.07035 seconds)
# Step 289: 1.29840e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.1447e-08) (took 0.06806 seconds)
# Step 290: 1.29328e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.1244e-08) (took 0.12378 seconds)
# Step 291: 1.28817e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.1042e-08) (took 0.07270 seconds)
# Step 292: 1.28309e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.0841e-08) (took 0.07071 seconds)
# Step 293: 1.27802e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.0640e-08) (took 0.13162 seconds)
# Step 294: 1.27298e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.0440e-08) (took 0.07126 seconds)
# Step 295: 1.26796e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.0241e-08) (took 0.11487 seconds)
# Step 296: 1.26295e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (5.0043e-08) (took 0.11555 seconds)
# Step 297: 1.25797e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (4.9845e-08) (took 0.06894 seconds)
# Step 298: 1.25300e-05, stepsizes = 3.4e-02/2.0e-03: d. reduced by 0.39% (4.9648e-08) (took 0.06902 seconds)
# Step 299: 1.25300e-05, stepsizes = 3.4e-02/2.0e-03:  (took 0.13060 seconds)
# Step 300: 1.25300e-05, stepsizes = 3.4e-02/1.3e-03:  (took 0.21235 seconds)
# Step 301: 1.24971e-05, stepsizes = 3.4e-02/1.3e-03: d. reduced by 0.26% (3.2979e-08) (took 0.11660 seconds)
# Step 302: 1.24642e-05, stepsizes = 3.4e-02/1.3e-03: d. reduced by 0.26% (3.2893e-08) (took 0.07687 seconds)
# Step 303: 1.24314e-05, stepsizes = 3.4e-02/1.3e-03: d. reduced by 0.26% (3.2806e-08) (took 0.12150 seconds)
# Step 304: 1.23986e-05, stepsizes = 3.4e-02/1.3e-03: d. reduced by 0.26%
# Step 415: 9.79333e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.8805e-08) (took 0.12003 seconds)
# Step 416: 9.79333e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13265 seconds)
# Step 417: 9.75468e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.8652e-08) (took 0.06867 seconds)
# Step 418: 9.75468e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13161 seconds)
# Step 419: 9.71618e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.8499e-08) (took 0.11680 seconds)
# Step 420: 9.67783e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.8347e-08) (took 0.10764 seconds)
# Step 421: 9.67783e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13383 seconds)
# Step 422: 9.67783e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13028 seconds)
# Step 423: 9.63964e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.8196e-08) (took 0.11649 seconds)
# Step 424: 9.63964e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13116 seconds)
# Step 425: 9.63964e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13491 seconds)
# Step 426: 9.60159e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.8045e-08) (took 0.11762 seconds)
# Step 427: 9.60159e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13033 seconds)
# Step 428: 9.56370e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.7895e-08) (took 0.11713 seconds)
# Step 429: 9.56370e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13462 seconds)
# Step 430: 9.56370e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.20078 seconds)
# Step 431: 9.52595e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.7745e-08) (took 0.06991 seconds)
# Step 432: 9.52595e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.15210 seconds)
# Step 433: 9.52595e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13231 seconds)
# Step 434: 9.48836e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.7596e-08) (took 0.07261 seconds)
# Step 435: 9.48836e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13092 seconds)
# Step 436: 9.48836e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13615 seconds)
# Step 437: 9.48836e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13432 seconds)
# Step 438: 9.48836e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13835 seconds)
# Step 439: 9.48836e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13970 seconds)
# Step 440: 9.45091e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.7448e-08) (took 0.10508 seconds)
# Step 441: 9.45091e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13438 seconds)
# Step 442: 9.45091e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13178 seconds)
# Step 443: 9.45091e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13266 seconds)
# Step 444: 9.41361e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.7300e-08) (took 0.06867 seconds)
# Step 445: 9.37646e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.7153e-08) (took 0.11513 seconds)
# Step 446: 9.37646e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13455 seconds)
# Step 447: 9.37646e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13866 seconds)
# Step 448: 9.37646e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13069 seconds)
# Step 449: 9.37646e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13377 seconds)
# Step 450: 9.33945e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.7006e-08) (took 0.11111 seconds)
# Step 451: 9.33945e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13030 seconds)
# Step 452: 9.33945e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13328 seconds)
# Step 453: 9.30259e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.6860e-08) (took 0.07065 seconds)
# Step 454: 9.26587e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.6715e-08) (took 0.11476 seconds)
# Step 455: 9.22930e-06, stepsizes = 5.1e-02/2.0e-03: d. reduced by 0.39% (3.6570e-08) (took 0.06946 seconds)
# Step 456: 9.22930e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13224 seconds)
# Step 457: 9.22930e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13854 seconds)
# Step 458: 9.22930e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13760 seconds)
# Step 459: 9.22930e-06, stepsizes = 5.1e-02/2.0e-03:  (took 0.13471 seconds)
# Step 460: 9.19288e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.39% (3.6425e-08) (took 0.18447 seconds)
# Step 461: 9.16868e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.4196e-08) (took 0.07228 seconds)
# Step 462: 9.14455e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.4132e-08) (took 0.06837 seconds)
# Step 463: 9.12048e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.4068e-08) (took 0.06822 seconds)
# Step 464: 9.09648e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.4005e-08) (took 0.06756 seconds)
# Step 465: 9.09648e-06, stepsizes = 5.1e-02/1.3e-03:  (took 0.12985 seconds)
# Step 466: 9.07254e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3942e-08) (took 0.06956 seconds)
# Step 467: 9.07254e-06, stepsizes = 5.1e-02/1.3e-03:  (took 0.13164 seconds)
# Step 468: 9.07254e-06, stepsizes = 5.1e-02/1.3e-03:  (took 0.13964 seconds)
# Step 469: 9.07254e-06, stepsizes = 5.1e-02/1.3e-03:  (took 0.13057 seconds)
# Step 470: 9.04866e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3879e-08) (took 0.17216 seconds)
# Step 471: 9.02484e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3816e-08) (took 0.07103 seconds)
# Step 472: 9.00109e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3753e-08) (took 0.06949 seconds)
# Step 473: 8.97740e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3691e-08) (took 0.11571 seconds)
# Step 474: 8.95377e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3629e-08) (took 0.06991 seconds)
# Step 475: 8.95377e-06, stepsizes = 5.1e-02/1.3e-03:  (took 0.13052 seconds)
# Step 476: 8.93020e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3567e-08) (took 0.11484 seconds)
# Step 477: 8.90670e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3504e-08) (took 0.06964 seconds)
# Step 478: 8.88325e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3443e-08) (took 0.11434 seconds)
# Step 479: 8.85987e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3381e-08) (took 0.07018 seconds)
# Step 480: 8.83655e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3319e-08) (took 0.17069 seconds)
# Step 481: 8.83655e-06, stepsizes = 5.1e-02/1.3e-03:  (took 0.13628 seconds)
# Step 482: 8.81330e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3258e-08) (took 0.07226 seconds)
# Step 483: 8.79010e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3197e-08) (took 0.06880 seconds)
# Step 484: 8.76696e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3135e-08) (took 0.07019 seconds)
# Step 485: 8.74389e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3075e-08) (took 0.06900 seconds)
# Step 486: 8.72087e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.3014e-08) (took 0.06994 seconds)
# Step 487: 8.69792e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.2953e-08) (took 0.07117 seconds)
# Step 488: 8.67503e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.2893e-08) (took 0.06803 seconds)
# Step 489: 8.65220e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.2833e-08) (took 0.06926 seconds)
# Step 490: 8.65220e-06, stepsizes = 5.1e-02/1.3e-03:  (took 0.18589 seconds)
# Step 491: 8.62942e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.2773e-08) (took 0.11580 seconds)
# Step 492: 8.60671e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.2713e-08) (took 0.07136 seconds)
# Step 493: 8.58406e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.2653e-08) (took 0.13980 seconds)
# Step 494: 8.56146e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.2593e-08) (took 0.11701 seconds)
# Step 495: 8.56146e-06, stepsizes = 5.1e-02/1.3e-03:  (took 0.13484 seconds)
# Step 496: 8.53893e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.2534e-08) (took 0.06770 seconds)
# Step 497: 8.51646e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.2475e-08) (took 0.06673 seconds)
# Step 498: 8.49404e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.2415e-08) (took 0.11677 seconds)
# Step 499: 8.47168e-06, stepsizes = 5.1e-02/1.3e-03: d. reduced by 0.26% (2.2356e-08) (took 0.11522 seconds)
# ...
# Step 4848: 1.26985e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9366e-10) (took 0.06248 seconds)
# Step 4849: 1.26956e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9361e-10) (took 0.12803 seconds)
# Step 4850: 1.26927e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9354e-10) (took 0.10418 seconds)
# Step 4851: 1.26897e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9347e-10) (took 0.06846 seconds)
# Step 4852: 1.26868e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9337e-10) (took 0.06515 seconds)
# Step 4853: 1.26839e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9338e-10) (took 0.06352 seconds)
# Step 4854: 1.26809e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9316e-10) (took 0.06694 seconds)
# Step 4855: 1.26780e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9319e-10) (took 0.10950 seconds)
# Step 4856: 1.26751e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9316e-10) (took 0.06825 seconds)
# Step 4857: 1.26721e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9307e-10) (took 0.06876 seconds)
# Step 4858: 1.26721e-06, stepsizes = 1.5e-02/1.2e-04:  (took 0.12863 seconds)
# Step 4859: 1.26721e-06, stepsizes = 1.5e-02/1.2e-04:  (took 0.12955 seconds)
# Step 4860: 1.26692e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9301e-10) (took 0.09350 seconds)
# Step 4861: 1.26663e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9294e-10) (took 0.06501 seconds)
# Step 4862: 1.26634e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9282e-10) (took 0.06464 seconds)
# Step 4863: 1.26604e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9282e-10) (took 0.06416 seconds)
# Step 4864: 1.26575e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9270e-10) (took 0.06330 seconds)
# Step 4865: 1.26546e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9255e-10) (took 0.06484 seconds)
# Step 4866: 1.26516e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9261e-10) (took 0.06600 seconds)
# Step 4867: 1.26487e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9258e-10) (took 0.06303 seconds)
# Step 4868: 1.26458e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9239e-10) (took 0.06301 seconds)
# Step 4869: 1.26458e-06, stepsizes = 1.5e-02/1.2e-04:  (took 0.12818 seconds)
# Step 4870: 1.26458e-06, stepsizes = 1.5e-02/1.2e-04:  (took 0.19457 seconds)
# Step 4871: 1.26429e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9239e-10) (took 0.07025 seconds)
# Step 4872: 1.26400e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9241e-10) (took 0.06813 seconds)
# Step 4873: 1.26370e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9216e-10) (took 0.06736 seconds)
# Step 4874: 1.26341e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9223e-10) (took 0.06716 seconds)
# Step 4875: 1.26312e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9201e-10) (took 0.06478 seconds)
# Step 4876: 1.26283e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9214e-10) (took 0.06497 seconds)
# Step 4877: 1.26253e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9200e-10) (took 0.06797 seconds)
# Step 4878: 1.26224e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9188e-10) (took 0.06541 seconds)
# Step 4879: 1.26224e-06, stepsizes = 1.5e-02/1.2e-04:  (took 0.12522 seconds)
# Step 4880: 1.26195e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9181e-10) (took 0.09543 seconds)
# Step 4881: 1.26166e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9179e-10) (took 0.11288 seconds)
# Step 4882: 1.26137e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9166e-10) (took 0.06523 seconds)
# Step 4883: 1.26137e-06, stepsizes = 1.5e-02/1.2e-04:  (took 0.12602 seconds)
# Step 4884: 1.26108e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9169e-10) (took 0.06635 seconds)
# Step 4885: 1.26078e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9156e-10) (took 0.06643 seconds)
# Step 4886: 1.26049e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9155e-10) (took 0.06625 seconds)
# Step 4887: 1.26049e-06, stepsizes = 1.5e-02/1.2e-04:  (took 0.12718 seconds)
# Step 4888: 1.26020e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9139e-10) (took 0.06424 seconds)
# Step 4889: 1.25991e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9134e-10) (took 0.06411 seconds)
# Step 4890: 1.25962e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9130e-10) (took 0.09056 seconds)
# Step 4891: 1.25962e-06, stepsizes = 1.5e-02/1.2e-04:  (took 0.12487 seconds)
# Step 4892: 1.25933e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9126e-10) (took 0.06848 seconds)
# Step 4893: 1.25904e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9114e-10) (took 0.06760 seconds)
# Step 4894: 1.25874e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9117e-10) (took 0.11267 seconds)
# Step 4895: 1.25845e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9097e-10) (took 0.06532 seconds)
# Step 4896: 1.25845e-06, stepsizes = 1.5e-02/1.2e-04:  (took 0.12831 seconds)
# Step 4897: 1.25816e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9100e-10) (took 0.06662 seconds)
# Step 4898: 1.25787e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9087e-10) (took 0.06612 seconds)
# Step 4899: 1.25758e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9078e-10) (took 0.06630 seconds)
# Step 4900: 1.25729e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9080e-10) (took 0.09362 seconds)
# Step 4901: 1.25700e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9067e-10) (took 0.11656 seconds)
# Step 4902: 1.25671e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9071e-10) (took 0.06806 seconds)
# Step 4903: 1.25671e-06, stepsizes = 1.5e-02/1.2e-04:  (took 0.13235 seconds)
# Step 4904: 1.25642e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9051e-10) (took 0.11526 seconds)
# Step 4905: 1.25613e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9054e-10) (took 0.07078 seconds)
# Step 4906: 1.25584e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9036e-10) (took 0.06685 seconds)
# Step 4907: 1.25584e-06, stepsizes = 1.5e-02/1.2e-04:  (took 0.12520 seconds)
# Step 4908: 1.25555e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9034e-10) (took 0.06816 seconds)
# Step 4909: 1.25555e-06, stepsizes = 1.5e-02/1.2e-04:  (took 0.13253 seconds)
# Step 4910: 1.25526e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9032e-10) (took 0.16917 seconds)
# Step 4911: 1.25526e-06, stepsizes = 1.5e-02/1.2e-04:  (took 0.13356 seconds)
# Step 4912: 1.25497e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9018e-10) (took 0.06656 seconds)
# Step 4913: 1.25468e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.9026e-10) (took 0.11049 seconds)
# Step 4914: 1.25439e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.
-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.8495e-10) (took 0.06925 seconds)
# Step 5000: 1.23225e-06, stepsizes = 1.5e-02/1.2e-04: d. reduced by 0.02% (2.8503e-10) (took 0.09482 seconds)

# %%
print(np.argmax(fmodel.predictions(adversarial3)), label)

plt.figure()
print("True Image Deprocessed:")
img = plt.imshow(deprocess_inception(image[0]))
img.set_cmap('hot')
plt.axis('off')
plt.show()

print("Adversarial Image Deprocessed:")
plt.figure()
img = plt.imshow(deprocess_inception(adversarial3))
img.set_cmap('hot')
plt.axis('off')
plt.show()

print("Perturbation*10:")
plt.figure()
img = plt.imshow(deprocess_inception(np.abs((adversarial3 - image[0]))*10))
img.set_cmap('hot')
plt.axis('off')
plt.show()
# Out:
# 1 0
# True Image Deprocessed:
# Adversarial Image Deprocessed:
# Perturbation*10:

# %%
print("Chest X-Ray")
model = load_model('/home/sgf2/DBMI_server/adversarial_attacks/cxr/models/wb_model.h5')
(X_test, cxr_y_test,
 X_test_pgd_wb, X_test_pgd_bb) = getResults('/home/sgf2/DBMI_server/adversarial_attacks/cxr')

# %%
display_adv_examples(2, X_test_pgd_wb, model, X_test, cxr_y_test, verbose = True, X_test_bb = X_test_pgd_bb)
display_adv_examples(8378, X_test_pgd_wb, model, X_test, cxr_y_test, verbose = True, X_test_bb = X_test_pgd_bb)
# Out:
# Chest X-Ray
# Truth: [[1. 0.]]
# Model predict on true image: [[0.9975188  0.00248129]]
# Model predict on adversarial image: [[2.3234385e-11 1.0000000e+00]]
# Model predict on BB adversarial image: [[0.0220151 0.9779849]]
#
# True Image Deprocessed:
# Adversarial Image Deprocessed:
# Perturbation:
# Truth: [[0. 1.]]
# Model predict on true image: [[0.2069369  0.79306316]]
# Model predict on adversarial image: [[1.0000000e+00 1.0546143e-11]]
# Model predict on BB adversarial image: [[0.9799585  0.02004154]]
#
# True Image Deprocessed:
# Adversarial Image Deprocessed:
# Perturbation:

# %%
# foolbox based attack

import foolbox
from foolbox.models import KerasModel
from foolbox.attacks import LBFGSAttack
from foolbox.criteria import TargetClassProbability

fmodel = KerasModel(model, bounds=(0, 255))

# run the attack
attack = LBFGSAttack(model=fmodel, criterion=TargetClassProbability(1, p=.95))

image = np.asarray(X_test[2])
label = np.argmax(model.predict(image))

adversarial = attack( image , label)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-df53bc5d6662> in <module>
#      12
#      13 image = np.asarray(X_test[2])
# ---> 14 label = np.argmax(model.predict(image))
#      15
#      16 adversarial = attack( image , label)
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1147                              'argument.')
#    1148         # Validate user data.
# -> 1149         x, _, _ = self._standardize_user_data(x)
#    1150         if self.stateful:
#    1151             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     126                         ': expected ' + names[i] + ' to have ' +
#     127                         str(len(shape)) + ' dimensions, but got array '
# --> 128                         'with shape ' + str(data_shape))
#     129                 if not check_batch_axis:
#     130                     data_shape = data_shape[1:]
#
# ValueError: Error when checking input: expected input_1 to have 4 dimensions, but got array with shape (224, 224, 3)

# %%
print("Melanoma")
model = load_model('/home/sgf2/DBMI_server/adversarial_attacks/melanoma/models/wb_model.h5')

(X_test, derm_y_test,
 X_test_pgd_wb, X_test_pgd_bb) = getResults('/home/sgf2/DBMI_server/adversarial_attacks/melanoma')

display_adv_examples(1, X_test_pgd_wb, model, X_test, derm_y_test, verbose = True, X_test_bb = X_test_pgd_bb)
display_adv_examples(531, X_test_pgd_wb, model, X_test, derm_y_test, verbose = True, X_test_bb = X_test_pgd_bb)
# Out:
# Melanoma
# Truth: [[1. 0.]]
# Model predict on true image: [[0.9906974  0.00930259]]
# Model predict on adversarial image: [[1.0917776e-14 1.0000000e+00]]
# Model predict on BB adversarial image: [[0.04510245 0.9548976 ]]
#
# True Image Deprocessed:
# Adversarial Image Deprocessed:
# Perturbation:
# Truth: [[0. 1.]]
# Model predict on true image: [[0.22231914 0.7776809 ]]
# Model predict on adversarial image: [[1.0000000e+00 2.7623002e-15]]
# Model predict on BB adversarial image: [[9.9916124e-01 8.3882501e-04]]
#
# True Image Deprocessed:
# Adversarial Image Deprocessed:
# Perturbation:

# %% [markdown]
# # Toy Model Confidence Plots

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

def confidence_plot(preds = [0.93706179, 0.06293821],
                  labels = ["Pneumothorax", "Normal"],
                   isNormal = True, hideText = False,
                   diseaseTop = False):
    sns.set(font_scale=2)

    if isNormal:
        pal = ["red", "green"]
    else:
        pal = ["green", "red"]
        
    if not diseaseTop:
        preds.reverse()
        pal.reverse()
        labels.reverse()
        
    d = {'Model Confidence' : pd.Series(preds, index=['a', 'b']),
         'Diagnosis' : pd.Series(labels, index=['a', 'b'])}
    ax = sns.barplot(x="Model Confidence", y="Diagnosis",
                     data=pd.DataFrame(d), palette=pal)
    ax.set_xlim((0,1))
    ax.set_ylabel('') 
    if hideText:
        ax.set_yticklabels(['',''])
        ax.set_xlabel('')
        ax.set_xticklabels('')
    plt.show()

# %% [markdown]
# ### Generate plots

# %%
hide_diag = False
confidence_plot([ 0.00930259, 0.9906974],
               ["Malignant", "Benign"],
               isNormal = True, hideText = hide_diag)

confidence_plot([1.0000000e+00, 2.2059932e-11],
               ["Malignant", "Benign"],
               isNormal = True, hideText = hide_diag)

# %%
hide_diag = False
confidence_plot([ 0.048, 1 - 0.048],
               ["Diabetic \nRetinopathy", "Healthy"],
               isNormal = True, hideText = hide_diag)

confidence_plot([1.0000000e+00, 2.2059932e-11],
               ["Diabetic \nRetinopathy", "Healthy"],
               isNormal = True, hideText = hide_diag)

# %% [markdown]
# # ROC, Sensitivity, Specificity

# %% [markdown]
# ## Load Model Output

# %%
import numpy as np
import os
os.chdir('/home/sgf2/DBMI_server/adversarial_attacks/')

y_test_dr = np.load('retinopathy/data/val_test_y.npy')
preds_dr = np.load('retinopathy/data/winning_model_preds.npy') #from model 30 epochs is best right now
print((preds_dr.shape, y_test_dr.shape))

y_test_cxr = np.load('cxr/data/val_test_y.npy')
preds_cxr = np.load('cxr/data/winning_model_preds.npy')
print((y_test_cxr.shape, preds_cxr.shape))

y_test_derm = np.load('melanoma/data/val_test_y.npy')
preds_derm = np.load('melanoma/data/winning_model_preds.npy')
print((preds_derm.shape, y_test_derm.shape))
# Out:
# ((10644, 2), (10644, 2))
# ((8383, 2), (8383, 2))
# ((533, 2), (533, 2))

# %% [markdown]
# ## Plot Roc

# %%
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import auc

# Generate roc curves from lists of: predictions, labels, and titles
def plot_roc(preds_list, y_test_list ,
             curve_titles_list = None,
             mainTitle = 'Receiver operating characteristic curve'):
    
    # If input is not list, convert it to a list
    if type(preds_list) is not list:
        preds_list = [preds_list]
        y_test_list = [y_test_list]
        if curve_titles_list is not None:
            curve_titles_list = [curve_titles_list]
        
    assert len(preds_list) == len(y_test_list), "Must provide same number of preds and labels."
    
    # Set up figure of size 5x5
    fig_size = plt.rcParams["figure.figsize"]
    fig_size[0] = 5
    fig_size[1] = 5
    plt.rcParams["figure.figsize"] = fig_size
        
    # Cycle through lists of predictions and labels and generate roc curves
    for preds, y_test, curve_title in zip(preds_list, y_test_list, curve_titles_list):
        fpr, tpr, thresholds = metrics.roc_curve(y_test[:,1], preds[:,1])
        auc_score = auc(fpr,tpr)
        curve_label = curve_title + ' (AUC=%0.2f)' % float(auc_score)
        if len(preds_list) == 1:
            plt.plot(fpr,tpr,label= curve_label, color="darkorange")
        else:
            plt.plot(fpr,tpr,label= curve_label)
    
    # Plot diagonal line
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
   
    # Set axes and titles
    plt.xlim([0, 1.0])
    plt.ylim([0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(mainTitle)
    plt.legend(loc="lower right")
    
    # Display
    plt.show()

plot_roc([preds_dr, preds_cxr, preds_derm],
         [y_test_dr, y_test_cxr, y_test_derm],
         ['Retinopathy', 'Pneumothorax', 'Melanoma'],
         "Performance of baseline diagnostic models")

#plot_roc(preds_dr,
#         y_test_dr,
#         'Retinopathy',
#         "Performance of baseline diagnostic models")

# %% [markdown]
# ### DR

# %%
# Recall of positive class is sensitivity, recall of negative class is spec
from sklearn.metrics import classification_report
print("DR performance:")
print(classification_report(y_test_dr[:,1], (preds_dr[:,1] > 0.14) ))
# Out:
# DR performance:
#              precision    recall  f1-score   support
#
#         0.0       0.96      0.80      0.87      8715
#         1.0       0.48      0.85      0.62      1929
#
# avg / total       0.87      0.81      0.82     10644

# %% [markdown]
# ### CXR

# %%
print("CXR performance:")
print(classification_report(y_test_cxr[:,1], (preds_cxr[:,1] > 0.025)))
# Out:
# CXR performance:
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.82      0.90      7684
#         1.0       0.31      0.90      0.47       699
#
# avg / total       0.93      0.83      0.86      8383

# %% [markdown]
# ### Derm

# %%
print("Derm performance:")
print(classification_report(y_test_derm[:,1],  (preds_derm[:,1] > 0.02)))
# Out:
# Derm performance:
#              precision    recall  f1-score   support
#
#         0.0       0.91      0.73      0.81       398
#         1.0       0.50      0.80      0.61       135
#
# avg / total       0.81      0.74      0.76       533
